# %%
import requests
from bs4 import BeautifulSoup

# %%
# working with 2025 data first
raw_html = requests.get('https://www.boxofficemojo.com/month/february/2025/?grossesOption=totalGrosses')
soup_doc = BeautifulSoup(raw_html.content, "html.parser")
print(soup_doc.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo">
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr-rw';
# ...

# %%
movies = soup_doc.find_all('tr')[1:]   # consistent container for all the movies in 2025
movies
# Out:
# [<tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank mojo-sort-column">1</td><td class="a-text-left mojo-field-type-release mojo-cell-wide"><a class="a-link-normal" href="/release/rl2597421825/?ref_=bo_md_table_1">Captain America: Brave New World</a></td><td class="a-text-left mojo-field-type-genre hidden">-</td><td class="a-text-right mojo-field-type-money hidden">-</td><td class="a-text-right mojo-field-type-duration hidden">-</td><td class="a-text-right mojo-field-type-money mojo-estimatable">$147,189,885</td><td class="a-text-right mojo-field-type-positive_integer">4,105</td><td class="a-text-right mojo-field-type-money">$88,842,603</td><td class="a-text-right mojo-field-type-percent">60.4%</td><td class="a-text-right mojo-field-type-positive_integer">4,105</td><td class="a-text-left mojo-field-type-date a-nowrap">Feb 14</td><td class="a-text-left mojo-field-type-date a-nowrap">-</td><td class="a-text-left mojo-field-type-studio"><a class="a-link-nor
# ...

# %%
movies[0]  # first row
# Out:
# <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank mojo-sort-column">1</td><td class="a-text-left mojo-field-type-release mojo-cell-wide"><a class="a-link-normal" href="/release/rl2597421825/?ref_=bo_md_table_1">Captain America: Brave New World</a></td><td class="a-text-left mojo-field-type-genre hidden">-</td><td class="a-text-right mojo-field-type-money hidden">-</td><td class="a-text-right mojo-field-type-duration hidden">-</td><td class="a-text-right mojo-field-type-money mojo-estimatable">$147,189,885</td><td class="a-text-right mojo-field-type-positive_integer">4,105</td><td class="a-text-right mojo-field-type-money">$88,842,603</td><td class="a-text-right mojo-field-type-percent">60.4%</td><td class="a-text-right mojo-field-type-positive_integer">4,105</td><td class="a-text-left mojo-field-type-date a-nowrap">Feb 14</td><td class="a-text-left mojo-field-type-date a-nowrap">-</td><td class="a-text-left mojo-field-type-studio"><a class="a-link-norm
# ...

# %%
# first row's movie title
first_title = movies[0].find_all('a')[0].text
first_title
# Out:
# 'Captain America: Brave New World'

# %%
# first row's movie release date
first_release = movies[0].find_all('td')[10].text
first_release
# Out:
# 'Feb 14'

# %%
first_list = []

first_list.append(first_title)
first_list.append(first_release)

first_list
# Out:
# ['Captain America: Brave New World', 'Feb 14']

# %%
# loop through every row on the page
i = 0
for movie in movies:
    print(movies[i].find_all('a')[0].text)
    print(movies[i].find_all('td')[10].text)
    print("-----------------")
    i = i+1
# Out:
# Captain America: Brave New World
# Feb 14
# -----------------
# Heart Eyes
# Feb 7
# -----------------
# Paddington in Peru
# Feb 14
# -----------------
# The Monkey
# Feb 21
# -----------------
# Ne Zha 2
# Feb 14
# -----------------
# Love Hurts
# Feb 7
# -----------------
# Becoming Led Zeppelin
# Feb 7
# -----------------
# The Unbreakable Boy
# Feb 21
# -----------------
# Attack on Titan the Movie: The Last Attack
# Feb 10
# -----------------
# 2025 Oscar Nominated Short Films: Live Action
# Feb 14
# -----------------
# Chhaava
# Feb 14
# -----------------
# Parasite
# Feb 7
# -----------------
# Legends of the Condor Heroes: The Gallants
# Feb 21
# -----------------
# Cleaner
# Feb 21
# -----------------
# Bring Them Down
# Feb 7
# -----------------
# Parthenope
# Feb 7
# -----------------
# Armand
# Feb 7
# -----------------
# Dark Nuns
# Feb 7
# -----------------
# Universal Language
# Feb 14
# -----------------
# A Woman Is a Woman
# Feb 7
# -----------------
# ...

# %%
# saving result to a list
all_list = []
i = 0
for movie in movies:
    temp_list = [] 
    temp_list.append(movies[i].find_all('a')[0].text)
    temp_list.append(movies[i].find_all('td')[10].text)
    i = i+1
    all_list.append(temp_list)

all_list
# Out:
# [['Captain America: Brave New World', 'Feb 14'],
#  ['Heart Eyes', 'Feb 7'],
#  ['Paddington in Peru', 'Feb 14'],
#  ['The Monkey', 'Feb 21'],
#  ['Ne Zha 2', 'Feb 14'],
#  ['Love Hurts', 'Feb 7'],
#  ['Becoming Led Zeppelin', 'Feb 7'],
#  ['The Unbreakable Boy', 'Feb 21'],
#  ['Attack on Titan the Movie: The Last Attack', 'Feb 10'],
#  ['2025 Oscar Nominated Short Films: Live Action', 'Feb 14'],
#  ['Chhaava', 'Feb 14'],
#  ['Parasite', 'Feb 7'],
#  ['Legends of the Condor Heroes: The Gallants', 'Feb 21'],
#  ['Cleaner', 'Feb 21'],
#  ['Bring Them Down', 'Feb 7'],
#  ['Parthenope', 'Feb 7'],
#  ['Armand', 'Feb 7'],
#  ['Dark Nuns', 'Feb 7'],
#  ['Universal Language', 'Feb 14'],
#  ['A Woman Is a Woman', 'Feb 7'],
#  ['The Annihilation of Fish', 'Feb 14'],
#  ['I Love You Forever', 'Feb 7'],
#  ["When I'm Ready", 'Feb 7'],
#  ['Ex-Husbands', 'Feb 21'],
#  ['Rounding', 'Feb 14'],
#  ['The Quiet Ones', 'Feb 21']]

# %%
all_movies = []

# Loop through each year from 2015 to 2025
for year in range(2015, 2026):
    url = f'https://www.boxofficemojo.com/month/february/{year}/?grossesOption=totalGrosses'
    raw_html = requests.get(url)
    soup_doc = BeautifulSoup(raw_html.content, "html.parser")
    
    # Find all movie rows (skip the first row if it's a header)
    movies = soup_doc.find_all('tr')[1:]

    for movie in movies:
        try:
            title = movie.find_all('a')[0].text  # Movie Title
            release_date = movie.find_all('td')[10].text  # Release date
            day = int(release_date.split()[1])  # Extract day part
    
            # Filter movies released between Feb 1 and Feb 14
            if 1 <= day <= 14:
                all_valentines_movies.append([year, title, release_date])
            all_movies.append([title, release_date, year])  # Store with year
            
        except (IndexError, AttributeError):
            # Skip rows that don't have expected data
            continue

# %%
# Print collected movies
for movie in all_movies:
    print(movie)
# Out:
# ['Fifty Shades of Grey', 'Feb 13', 2015]
# ['The SpongeBob Movie: Sponge Out of Water', 'Feb 6', 2015]
# ['Kingsman: The Secret Service', 'Feb 13', 2015]
# ['Focus', 'Feb 27', 2015]
# ['Jupiter Ascending', 'Feb 6', 2015]
# ['McFarland, USA', 'Feb 20', 2015]
# ['The DUFF', 'Feb 20', 2015]
# ['The Lazarus Effect', 'Feb 27', 2015]
# ['Seventh Son', 'Feb 6', 2015]
# ['Hot Tub Time Machine 2', 'Feb 20', 2015]
# ['A la mala', 'Feb 27', 2015]
# ['What We Do in the Shadows', 'Feb 13', 2015]
# ['Wild Tales', 'Feb 20', 2015]
# ['Old Fashioned', 'Feb 6', 2015]
# ["'71", 'Feb 27', 2015]
# ['Gett', 'Feb 13', 2015]
# ['The Last: Naruto the Movie', 'Feb 20', 2015]
# ['Deli Man', 'Feb 27', 2015]
# ['Somewhere Only We Know', 'Feb 13', 2015]
# ['Badlapur', 'Feb 20', 2015]
# ['The Hunting Ground', 'Feb 27', 2015]
# ['Maps to the Stars', 'Feb 27', 2015]
# ['Ballet 422', 'Feb 6', 2015]
# ['Shamitabh', 'Feb 6', 2015]
# ['Zhongkui: Snow Girl and the Dark Crystal', 'Feb 27', 2015]
# ...
